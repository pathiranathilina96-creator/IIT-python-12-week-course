# %% [markdown]
# # IIT python class

# %% [markdown]
# ## week 01 homeworks

# %% [markdown]
# very first command - print

# %%
print("hello sri lanka")
# Out:
# hello sri lanka

# %%
print('ytr')
# Out:
# ytr
