# %%
x=10
y="Sri Lanka"
z=75.80
print(x)
print(y)
print(z)
# Out:
# 10
# Sri Lanka
# 75.8

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(type(Z))
#
# NameError: name 'Z' is not defined

# %%
print(type(z))
# Out:
# <class 'float'>
